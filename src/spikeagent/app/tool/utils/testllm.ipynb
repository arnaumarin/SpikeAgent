# %%
from custom_class import ChatAnthropic_H
import os
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
print(os.getenv("HARVARD_API_KEY"))
# Out:
# Ud1VYm9kJTtKvlaqCLwG5GhW1I24hniYAGc93tA33JG5ujjy

# %%
from custom_class import ChatAnthropic_H
import os

llm = ChatAnthropic_H(model='claude-sonnet-4-20250514-v1', harvard_api_key="r5Y3YcUi6YsT6m11xU0UoiUFHG7S7nqL")

llm.invoke("Hello, how are you?")
# Out:
# AIMessage(content="Hello! I'm doing well, thank you for asking. I'm here and ready to help with whatever you'd like to discuss or work on. How are you doing today?", additional_kwargs={}, response_metadata={'id': 'msg_bdrk_01BCUM9LJUmoB2ENBbR8eAmM', 'model': 'claude-sonnet-4-20250514', 'stop_reason': 'end_turn', 'stop_sequence': None, 'usage': {'input_tokens': 13, 'cache_creation_input_tokens': 0, 'cache_read_input_tokens': 0, 'output_tokens': 39}}, id='run--25bdb026-fb66-455b-a4d2-89ac73124b42-0')
